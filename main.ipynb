# %%
import pandas as pd

# %%
df = pd.read_csv('data/investments_VC.csv', encoding='latin-1')
print(df.shape)
print(df.info())
# Out:
# (54294, 39)
# <class 'pandas.DataFrame'>
# RangeIndex: 54294 entries, 0 to 54293
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   permalink             49438 non-null  str
#  1   name                  49437 non-null  str
#  2   homepage_url          45989 non-null  str
#  3   category_list         45477 non-null  str
#  4    market               45470 non-null  str
#  5   funding_total_usd     49438 non-null  str
#  6   status                48124 non-null  str
#  7   country_code          44165 non-null  str
#  8   state_code            30161 non-null  str
#  9   region                44165 non-null  str
#  10  city                  43322 non-null  str
#  11  funding_rounds        49438 non-null  float64
#  12  founded_at            38554 non-null  str
#  13  founded_month         38482 non-null  str
#  14  founded_quarter       38482 non-null  str
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 54294 entries, 0 to 54293
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   permalink             49438 non-null  str
#  1   name                  49437 non-null  str
#  2   homepage_url          45989 non-null  str
#  3   category_list         45477 non-null  str
#  4   market                45470 non-null  str
#  5   funding_total_usd     49438 non-null  str
#  6   status                48124 non-null  str
#  7   country_code          44165 non-null  str
#  8   state_code            30161 non-null  str
#  9   region                44165 non-null  str
#  10  city                  43322 non-null  str
#  11  funding_rounds        49438 non-null  float64
#  12  founded_at            38554 non-null  str
#  13  founded_month         38482 non-null  str
#  14  founded_quarter       38482 non-null  str
#  15  founded_year          38482 non-null  float64
# ...

# %%
drop_cols = [
    'permalink',
    'name',
    'homepage_url'
]

df = df.drop(columns=drop_cols)

# %%
df['status'].value_counts(dropna=False)
# Out:
# status
# operating    41829
# NaN           6170
# acquired      3692
# closed        2603
# Name: count, dtype: int64

# %%
df[df['status'].isna()][
    ['funding_total_usd', 'funding_rounds']
].describe()
# Out:
#        funding_rounds
# count     1314.000000
# mean         1.535769
# std          1.123324
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         10.000000

# %%
df['status'].isna().sum()
# Out:
# np.int64(6170)

# %%
df[df['status'].isna()][[
    'first_funding_at',
    'last_funding_at'
]].describe(include='all')
# Out:
#        first_funding_at last_funding_at
# count              1314            1314
# unique              693             609
# top          2012-09-01      2013-09-01
# freq                 19              21

# %%
df[df['status'].isna()]['founded_year'].describe()
# Out:
# count     918.000000
# mean     2006.142702
# std         9.494664
# min      1947.000000
# 25%      2005.000000
# 50%      2010.000000
# 75%      2012.000000
# max      2014.000000
# Name: founded_year, dtype: float64

# %% [markdown]
# ## We separate dataset according to status of the startups
#
# 1. Unknown Labels Startups
# 2. Operating labels Startups
# 3. acquired or closed labels Startups

# %%
labeled_df = df[df['status'].isin(['acquired', 'closed'])].copy()
operating_df = df[df['status'] == 'operating'].copy()
unknown_df = df[df['status'].isna()].copy()

# %%
labeled_df['status'].value_counts()
# Out:
# status
# acquired    3692
# closed      2603
# Name: count, dtype: int64
